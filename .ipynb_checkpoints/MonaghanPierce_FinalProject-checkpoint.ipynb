# %% [markdown]
# # Introduction
# ### Shallow water gravity waves

# %% [markdown]
# ## Equations
# #

# %% [markdown]
# ## Numerical Methods

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import spdiags

# %%
# parameters

xf = 24900*1000 # circumference of earth at 45 deg lat (m)
tf = 14*24*60*60 #14 days in seconds
g = 9.81# gravitational constant

# grid
nx = 1000
nt = 1000

x = np.linspace(0,xf,nx)
t = np.linspace(0,tf,nt)

dt = t[1]-t[0]
dx = x[1]-x[0]

c = np.zeros(xf) # shallow water wave speed
lam = np.zeros(nx)
lam[x<=xt] = alpha1*dt/dx
lam[x>xt] = alpha2*dt/dx

# initial condition
u = np.nan*np.ones([nx,nt])
u[:,0] = np.exp(-(x**2) / 2)
u[:,1] = np.exp(-(x**2) / 2)

# matrix
data = np.array([(lam**2)*np.ones(nx), 2*(1-lam**2)*np.ones(nx), (lam**2)*np.ones(nx)])
diags = np.array([-1, 0, 1])
M = spdiags(data, diags, nx, nx).toarray()

# boundary condition
#Reflective BC
M[0,0] = 2-lam[0]**2
M[-1,-1] = 2-lam[-1]**2

# solve
for k in np.arange(nt-2):
    u[:,k+2] = np.matmul(M,u[:,k+1]) - u[:,k]

# %%
plt.figure(1)
plt.title("Progression of the Change in Alpha over Distance")
plt.plot(x,lam)
plt.xlabel('Distance in x (in 1000s km)')
plt.ylabel('Value of lambda')
# Out:
# Text(0, 0.5, 'Value of lambda')

# %% [markdown]
# ## Results

# %% [markdown]
# ## Figures

# %% [markdown]
# ## Video Walkthrough

# %% [markdown]
# ## References
